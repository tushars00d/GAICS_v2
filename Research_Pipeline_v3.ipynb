# %% [markdown]
# # 5-Layer Autonomous GenAI-Powered Cloud Defense Architecture
# ## Viva Panel Resolution: Large-Scale Rigorous Pipeline
#
# This notebook contains the fully optimized, dissertation-grade pipeline updated specifically to address the Viva Panel's ruthless review.

# %%
# 1. Clone the GitHub Repository into the Colab Environment
# !git clone https://github.com/tushars00d/GAICS_v2.git || echo "Already cloned"
# %cd GAICS_v2

# 2. Install dependencies
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'GAICS_v2'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 71 (delta 24), reused 68 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (71/71), 50.97 KiB | 10.19 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# /content/GAICS_v2/GAICS_v2

# %%
import os
import shutil

# 3. Locate the dataset you uploaded and move it into the repository's data folder
possible_paths = [
    "/content/cicids_subset.csv",
    "/content/data/cicids_subset.csv",
    "/content/sample_data/cicids_subset.csv",
    "/content/sample_data/data/cicids_subset.csv"
]

target_path = "/content/GAICS_v2/data/cicids_subset.csv"
os.makedirs("/content/GAICS_v2/data", exist_ok=True)

found = False
if os.path.exists(target_path):
    print(f"Dataset already in correct location: {target_path}")
    found = True
else:
    for path in possible_paths:
        if os.path.exists(path):
            print(f"Found dataset at {path}. Moving to {target_path}...")
            shutil.move(path, target_path)
            found = True
            break

if not found:
    print("\n[!] ERROR: cicids_subset.csv not found!")
    print("Please check where you uploaded it in Colab and ensure the name is exactly 'cicids_subset.csv'")
else:
    print("\n[*] Dataset is ready. Proceeding with Pipeline.")
# Out:
# Dataset already in correct location: /content/GAICS_v2/data/cicids_subset.csv
#
# [*] Dataset is ready. Proceeding with Pipeline.

# %% [markdown]
# ### Phase 1: High-Performance Generative Pre-training (Tabular DDPM)
# Using Mixed Precision (AMP) to generate synthetic samples and augment the real CIC-IDS-2018 dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from training.train_ddpm import train_ddpm

sns.set_theme(style="whitegrid")

ddpm_model, ddpm_history = train_ddpm("configs/default.yaml")

plt.figure(figsize=(10, 4))
plt.plot(ddpm_history['loss'], label="DDPM MSE Loss", color='purple', linewidth=2)
plt.title("Tabular DDPM Generative Pre-training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# [!] Real dataset not found at data/cicids_subset.csv.
# [!] FATAL: Viva panel explicitly banned simulated data (synthetic mirage).
# [*] Falling back to downloading a public benchmark subset of real network traffic...
# VIVA PANEL MANDATE: You must place a real subset of CIC-IDS-2018 (e.g., 50,000 rows) at 'data/cicids_subset.csv'. Simulation is strictly prohibited to avoid circular validation.
#
# [WARNING] Falling back to a highly-noised 78-feature schema mimic so the pipeline runs.
# [WARNING] DO NOT show these specific F1-score results in your final dissertation.
#
# Data ingested: 80000 training, 20000 testing | Features: 78
# /content/GAICS_v2/training/train_ddpm.py:29: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_fp16)
# Training TabDDPM on cuda for 100 epochs | AMP: True
# 2026/04/29 07:32:15 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/04/29 07:32:15 INFO mlflow.store.db.utils: Updating database tables
# Epoch 1/100:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ddpm.py:57: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 1 Loss: 1.4841 | LR: 0.000100
# Epoch 2 Loss: 0.9900 | LR: 0.000100
# Epoch 3 Loss: 0.9776 | LR: 0.000100
# Epoch 4 Loss: 0.9622 | LR: 0.000100
# Epoch 5 Loss: 0.9456 | LR: 0.000100
# Epoch 6 Loss: 0.9263 | LR: 0.000099
# Epoch 7 Loss: 0.9062 | LR: 0.000099
# Epoch 8 Loss: 0.8833 | LR: 0.000099
# Epoch 9 Loss: 0.8603 | LR: 0.000098
# Epoch 10 Loss: 0.8356 | LR: 0.000098
# Epoch 11 Loss: 0.8127 | LR: 0.000098
# Epoch 12 Loss: 0.7882 | LR: 0.000097
# Epoch 13 Loss: 0.7652 | LR: 0.000096
# Epoch 14 Loss: 0.7411 | LR: 0.000096
# Epoch 15 Loss: 0.7198 | LR: 0.000095
# Epoch 16 Loss: 0.6980 | LR: 0.000095
# Epoch 17 Loss: 0.6776 | LR: 0.000094
# Epoch 18 Loss: 0.6581 | LR: 0.000093
# Epoch 19 Loss: 0.6395 | LR: 0.000092
# Epoch 20 Loss: 0.6208 | LR: 0.000091
# Epoch 21 Loss: 0.6048 | LR: 0.000090
# Epoch 22 Loss: 0.5868 | LR: 0.000090
# Epoch 23 Loss: 0.5734 | LR: 0.000089
# Epoch 24 Loss: 0.5567 | LR: 0.000088
# Epoch 25 Loss: 0.5441 | LR: 0.000086
# Epoch 26 Loss: 0.5290 | LR: 0.000085
# Epoch 27 Loss: 0.5190 | LR: 0.000084
# Epoch 28 Loss: 0.5075 | LR: 0.000083
# Epoch 29 Loss: 0.4955 | LR: 0.000082
# Epoch 30 Loss: 0.4865 | LR: 0.000081
# Epoch 31 Loss: 0.4732 | LR: 0.000079
# Epoch 32 Loss: 0.4635 | LR: 0.000078
# Epoch 33 Loss: 0.4534 | LR: 0.000077
# Epoch 34 Loss: 0.4455 | LR: 0.000075
# Epoch 35 Loss: 0.4367 | LR: 0.000074
# Epoch 36 Loss: 0.4268 | LR: 0.000073
# Epoch 37 Loss: 0.4205 | LR: 0.000071
# Epoch 38 Loss: 0.4159 | LR: 0.000070
# Epoch 39 Loss: 0.4073 | LR: 0.000068
# Epoch 40 Loss: 0.3988 | LR: 0.000067
# Epoch 41 Loss: 0.3913 | LR: 0.000065
# Epoch 42 Loss: 0.3855 | LR: 0.000064
# Epoch 43 Loss: 0.3797 | LR: 0.000062
# Epoch 44 Loss: 0.3741 | LR: 0.000061
# Epoch 45 Loss: 0.3709 | LR: 0.000059
# Epoch 46 Loss: 0.3642 | LR: 0.000058
# Epoch 47 Loss: 0.3626 | LR: 0.000056
# Epoch 48 Loss: 0.3551 | LR: 0.000055
# Epoch 49 Loss: 0.3500 | LR: 0.000053
# Epoch 50 Loss: 0.3496 | LR: 0.000052
# Epoch 51 Loss: 0.3440 | LR: 0.000050
# Epoch 52 Loss: 0.3406 | LR: 0.000048
# Epoch 53 Loss: 0.3373 | LR: 0.000047
# Epoch 54 Loss: 0.3316 | LR: 0.000045
# Epoch 55 Loss: 0.3327 | LR: 0.000044
# Epoch 56 Loss: 0.3282 | LR: 0.000042
# Epoch 57 Loss: 0.3273 | LR: 0.000041
# Epoch 58 Loss: 0.3198 | LR: 0.000039
# Epoch 59 Loss: 0.3199 | LR: 0.000038
# Epoch 60 Loss: 0.3177 | LR: 0.000036
# Epoch 61 Loss: 0.3147 | LR: 0.000035
# Epoch 62 Loss: 0.3130 | LR: 0.000033
# Epoch 63 Loss: 0.3116 | LR: 0.000032
# Epoch 64 Loss: 0.3093 | LR: 0.000030
# Epoch 65 Loss: 0.3048 | LR: 0.000029
# Epoch 66 Loss: 0.3068 | LR: 0.000027
# Epoch 67 Loss: 0.3021 | LR: 0.000026
# Epoch 68 Loss: 0.3022 | LR: 0.000025
# Epoch 69 Loss: 0.3009 | LR: 0.000023
# Epoch 70 Loss: 0.2978 | LR: 0.000022
# Epoch 71 Loss: 0.2971 | LR: 0.000021
# Epoch 72 Loss: 0.2954 | LR: 0.000019
# Epoch 73 Loss: 0.2950 | LR: 0.000018
# Epoch 74 Loss: 0.2933 | LR: 0.000017
# Epoch 75 Loss: 0.2980 | LR: 0.000016
# Epoch 76 Loss: 0.2931 | LR: 0.000015
# Epoch 77 Loss: 0.2931 | LR: 0.000014
# Epoch 78 Loss: 0.2929 | LR: 0.000012
# Epoch 79 Loss: 0.2921 | LR: 0.000011
# Epoch 80 Loss: 0.2894 | LR: 0.000010
# Epoch 81 Loss: 0.2902 | LR: 0.000010
# Epoch 82 Loss: 0.2898 | LR: 0.000009
# Epoch 83 Loss: 0.2908 | LR: 0.000008
# Epoch 84 Loss: 0.2912 | LR: 0.000007
# Epoch 85 Loss: 0.2908 | LR: 0.000006
# Epoch 86 Loss: 0.2914 | LR: 0.000005
# Epoch 87 Loss: 0.2879 | LR: 0.000005
# Epoch 88 Loss: 0.2873 | LR: 0.000004
# Epoch 89 Loss: 0.2895 | LR: 0.000004
# Epoch 90 Loss: 0.2898 | LR: 0.000003
# Epoch 91 Loss: 0.2872 | LR: 0.000002
# Epoch 92 Loss: 0.2869 | LR: 0.000002
# Epoch 93 Loss: 0.2900 | LR: 0.000002
# Epoch 94 Loss: 0.2890 | LR: 0.000001
# Epoch 95 Loss: 0.2890 | LR: 0.000001
# Epoch 96 Loss: 0.2862 | LR: 0.000001
# Epoch 97 Loss: 0.2881 | LR: 0.000000
# Epoch 98 Loss: 0.2882 | LR: 0.000000
# Epoch 99 Loss: 0.2929 | LR: 0.000000
# Epoch 100 Loss: 0.2895 | LR: 0.000000
# TabDDPM training complete. Model saved to checkpoints/tab_ddpm.pth

# %% [markdown]
# ### Phase 2: Robust Attention IDS Training
# Training the detection model using Focal Loss and Cosine Schedulers.

# %%
from training.train_ids import train_ids

ids_model, ids_history = train_ids("configs/default.yaml")

fig, ax1 = plt.subplots(figsize=(10, 4))
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Focal Loss', color='tab:red')
ax1.plot(ids_history['train_loss'], color='tab:red', label='Train Loss')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax2 = ax1.twinx()
ax2.set_ylabel('Macro F1 Score', color='tab:blue')
ax2.plot(ids_history['val_f1'], color='tab:blue', label='Val Macro F1')
ax2.tick_params(axis='y', labelcolor='tab:blue')

plt.title("Attention IDS Training Curve")
fig.tight_layout()
plt.show()
# Out:
# [!] Real dataset not found at data/cicids_subset.csv.
# [!] FATAL: Viva panel explicitly banned simulated data (synthetic mirage).
# [*] Falling back to downloading a public benchmark subset of real network traffic...
# VIVA PANEL MANDATE: You must place a real subset of CIC-IDS-2018 (e.g., 50,000 rows) at 'data/cicids_subset.csv'. Simulation is strictly prohibited to avoid circular validation.
#
# [WARNING] Falling back to a highly-noised 78-feature schema mimic so the pipeline runs.
# [WARNING] DO NOT show these specific F1-score results in your final dissertation.
# /content/GAICS_v2/training/train_ids.py:44: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_fp16)
# Data ingested: 80000 training, 20000 testing | Features: 78
# Training Attention IDS on cuda for 50 epochs | AMP: True | GradClip: 1.0
# Epoch 1/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 1 Loss: 0.0343 | Val Macro F1: 0.4594
# Epoch 2/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 2 Loss: 0.0280 | Val Macro F1: 0.4594
# Epoch 3/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 3 Loss: 0.0279 | Val Macro F1: 0.4594
# Epoch 4/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 4 Loss: 0.0279 | Val Macro F1: 0.4594
# Epoch 5/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 5 Loss: 0.0279 | Val Macro F1: 0.4594
# Epoch 6/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 6 Loss: 0.0278 | Val Macro F1: 0.4594
# Epoch 7/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 7 Loss: 0.0277 | Val Macro F1: 0.4594
# Epoch 8/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 8 Loss: 0.0278 | Val Macro F1: 0.4594
# Epoch 9/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 9 Loss: 0.0278 | Val Macro F1: 0.4594
# Epoch 10/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 10 Loss: 0.0276 | Val Macro F1: 0.4594
# Epoch 11/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 11 Loss: 0.0276 | Val Macro F1: 0.4594
# Epoch 12/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 12 Loss: 0.0276 | Val Macro F1: 0.4594
# Epoch 13/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 13 Loss: 0.0276 | Val Macro F1: 0.4594
# Epoch 14/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 14 Loss: 0.0275 | Val Macro F1: 0.4594
# Epoch 15/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 15 Loss: 0.0275 | Val Macro F1: 0.4594
# Epoch 16/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 16 Loss: 0.0274 | Val Macro F1: 0.4594
# Epoch 17/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 17 Loss: 0.0274 | Val Macro F1: 0.4594
# Epoch 18/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 18 Loss: 0.0274 | Val Macro F1: 0.4594
# Epoch 19/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 19 Loss: 0.0273 | Val Macro F1: 0.4594
# Epoch 20/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 20 Loss: 0.0274 | Val Macro F1: 0.4594
# Epoch 21/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 21 Loss: 0.0273 | Val Macro F1: 0.4594
# Epoch 22/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 22 Loss: 0.0273 | Val Macro F1: 0.4594
# Epoch 23/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 23 Loss: 0.0272 | Val Macro F1: 0.4594
# Epoch 24/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 24 Loss: 0.0272 | Val Macro F1: 0.4594
# Epoch 25/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 25 Loss: 0.0272 | Val Macro F1: 0.4594
# Epoch 26/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 26 Loss: 0.0273 | Val Macro F1: 0.4594
# Epoch 27/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 27 Loss: 0.0271 | Val Macro F1: 0.4594
# Epoch 28/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 28 Loss: 0.0271 | Val Macro F1: 0.4594
# Epoch 29/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 29 Loss: 0.0271 | Val Macro F1: 0.4594
# Epoch 30/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 30 Loss: 0.0270 | Val Macro F1: 0.4594
# Epoch 31/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 31 Loss: 0.0270 | Val Macro F1: 0.4594
# Epoch 32/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 32 Loss: 0.0271 | Val Macro F1: 0.4594
# Epoch 33/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 33 Loss: 0.0269 | Val Macro F1: 0.4594
# Epoch 34/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 34 Loss: 0.0269 | Val Macro F1: 0.4594
# Epoch 35/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 35 Loss: 0.0269 | Val Macro F1: 0.4594
# Epoch 36/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 36 Loss: 0.0269 | Val Macro F1: 0.4594
# Epoch 37/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 37 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 38/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 38 Loss: 0.0269 | Val Macro F1: 0.4594
# Epoch 39/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 39 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 40/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 40 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 41/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 41 Loss: 0.0269 | Val Macro F1: 0.4594
# Epoch 42/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 42 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 43/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 43 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 44/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 44 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 45/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 45 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 46/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 46 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 47/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 47 Loss: 0.0267 | Val Macro F1: 0.4594
# Epoch 48/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 48 Loss: 0.0267 | Val Macro F1: 0.4594
# Epoch 49/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 49 Loss: 0.0268 | Val Macro F1: 0.4594
# Epoch 50/50:   0%|          | 0/79 [00:00<?, ?it/s]/content/GAICS_v2/training/train_ids.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/training/train_ids.py:93: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Epoch 50 Loss: 0.0268 | Val Macro F1: 0.4594
# Attention IDS training complete. Model saved to checkpoints/attention_ids.pth

# %% [markdown]
# ### Phase 3: Explainability via SHAP (Addressing Viva Q8)
# Generating quantitative SHAP values to explain which features the Attention-IDS focuses on.

# %%
import shap
import torch
import numpy as np
from data.dataset_loaders import load_dataset
import yaml

with open("configs/default.yaml", "r") as f:
    config = yaml.safe_load(f)

_, test_loader, _, _ = load_dataset(config)
sample_data, _ = next(iter(test_loader))
sample_data = sample_data[:100].to(next(ids_model.parameters()).device)

explainer = shap.GradientExplainer(ids_model, sample_data)
shap_values = explainer.shap_values(sample_data)

shap.summary_plot(shap_values, sample_data.cpu().numpy(), feature_names=[f"F_{i}" for i in range(sample_data.shape[1])])
# Out:
# [!] Real dataset not found at data/cicids_subset.csv.
# [!] FATAL: Viva panel explicitly banned simulated data (synthetic mirage).
# [*] Falling back to downloading a public benchmark subset of real network traffic...
# VIVA PANEL MANDATE: You must place a real subset of CIC-IDS-2018 (e.g., 50,000 rows) at 'data/cicids_subset.csv'. Simulation is strictly prohibited to avoid circular validation.
#
# [WARNING] Falling back to a highly-noised 78-feature schema mimic so the pipeline runs.
# [WARNING] DO NOT show these specific F1-score results in your final dissertation.
#
# Data ingested: 80000 training, 20000 testing | Features: 78
# /tmp/ipykernel_7591/1107466305.py:17: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, sample_data.cpu().numpy(), feature_names=[f"F_{i}" for i in range(sample_data.shape[1])])
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:723: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(

# %% [markdown]
# ### Phase 4: Rigorous Ablation & Latency Profiling
# Profiles end-to-end inference latency in milliseconds and calculates robust multi-seed Ablation Statistics.

# %%
from evaluation.benchmark import run_ablation_studies
import IPython.display as display

results = run_ablation_studies("configs/default.yaml")

print("\nVisualizing Confusion Matrices from the final seed:\n")
display.display(display.Image(filename="plots/cm_clean.png"))
display.display(display.Image(filename="plots/cm_purified.png"))
# Out:
# [!] Real dataset not found at data/cicids_subset.csv.
# [!] FATAL: Viva panel explicitly banned simulated data (synthetic mirage).
# [*] Falling back to downloading a public benchmark subset of real network traffic...
# VIVA PANEL MANDATE: You must place a real subset of CIC-IDS-2018 (e.g., 50,000 rows) at 'data/cicids_subset.csv'. Simulation is strictly prohibited to avoid circular validation.
#
# [WARNING] Falling back to a highly-noised 78-feature schema mimic so the pipeline runs.
# [WARNING] DO NOT show these specific F1-score results in your final dissertation.
#
# Data ingested: 80000 training, 20000 testing | Features: 78
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:24: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:33: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# --- Latency & Line-Rate Feasibility Analysis ---
# Batch Size: 1024
# Raw IDS Inference: 0.96 ms | 1067271.42 events/sec
# DDPM Purification + IDS Inference: 63.52 ms | 16119.78 events/sec
# [!] WARNING: Purified Pipeline falls below 100k events/sec line-rate requirement. Hardware acceleration or parallel nodes needed.
#
# Running Security Ablation Studies over 5 seeds...
# Seed 1/5:   0%|          | 0/20 [00:00<?, ?it/s]/content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:125: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:133: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:140: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Seed 2/5:   0%|          | 0/20 [00:00<?, ?it/s]/content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:125: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:133: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:140: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Seed 3/5:   0%|          | 0/20 [00:00<?, ?it/s]/content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:125: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:133: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:140: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Seed 4/5:   0%|          | 0/20 [00:00<?, ?it/s]/content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:125: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:133: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:140: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# Seed 5/5:   0%|          | 0/20 [00:00<?, ?it/s]/content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:125: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:133: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# /content/GAICS_v2/GAICS_v2/evaluation/benchmark.py:140: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_fp16):
# --- Ablation Results (Mean ± Std) ---
# clean_f1: 0.4594 ± 0.0000
# fgsm_f1: 0.4594 ± 0.0000
# purified_f1: 0.4594 ± 0.0000
# clean_auc: 0.5036 ± 0.0000
# purified_auc: 0.1474 ± 0.0018
#
# Visualizing Confusion Matrices from the final seed:

# %% [markdown]
# ### Phase 5: Autonomous SOAR execution & Bayesian Governance
# Triggers the RAG-LLM Orchestrator to generate a response, which is then formally validated by the Bayesian PGM.

# %%
import json

# !pip install langchain langchain-core -q # Install missing libraries
from agents.agents import AutonomousResponseAgent

agent = AutonomousResponseAgent(config)

# Simulating a high severity anomaly over critical infrastructure
decision = agent.process_incident(telemetry_vector=[0.5, 0.9, -0.2, 1.5], severity_score=0.9, asset_criticality=0.4)

print("\nFinal Execution Trace Object:\n", json.dumps(decision, indent=4))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7591/1181369295.py in <cell line: 0>()
#       2
#       3 get_ipython().system('pip install langchain langchain-core -q # Install missing libraries')
# ----> 4 from agents.agents import AutonomousResponseAgent
#       5
#       6 agent = AutonomousResponseAgent(config)
#
# /content/GAICS_v2/GAICS_v2/agents/agents.py in <module>
#       2 import os
#       3 import torch
# ----> 4 from langchain.prompts import PromptTemplate
#       5 from agents.rag_pipeline import CyberThreatRAG
#       6 from agents.governance import TrustGovernanceEngine
#
# ModuleNotFoundError: No module named 'langchain.prompts'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
