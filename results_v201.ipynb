# %% [markdown]
# # 5-Layer Autonomous GenAI-Powered Cloud Defense Architecture
#
# This notebook is designed to execute the full architecture pipeline on Google Colab using a Free Tier T4 GPU.

# %%
# !git clone https://github.com/tushars00d/GAICS_v2.git
# %cd GAICS_v2
# !pip install -r requirements.txt
# Out:
# Cloning into 'GAICS_v2'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 39 (delta 9), reused 39 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 16.41 KiB | 16.41 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/GAICS_v2/GAICS_v2
# ...
#   Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 81.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 110.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 1. Train the Tabular DDPM (Layer 1)
# Synthesize data to augment the original dataset.

# %%
# !python -m training.train_ddpm
# Out:
# Loading dataset: nsl-kdd
# Data loaded: 8000 training samples, 2000 testing samples.
# Training TabDDPM on cuda for 50 epochs...
# Epoch 1 Loss: 1.8110
# Epoch 2 Loss: 1.0129
# Epoch 3 Loss: 0.9927
# Epoch 4 Loss: 0.9875
# Epoch 5 Loss: 0.9830
# Epoch 6 Loss: 0.9835
# Epoch 7 Loss: 0.9789
# Epoch 8 Loss: 0.9771
# Epoch 9 Loss: 0.9736
# Epoch 10 Loss: 0.9678
# Epoch 11 Loss: 0.9573
# Epoch 12 Loss: 0.9544
# Epoch 13 Loss: 0.9529
# Epoch 14 Loss: 0.9464
# Epoch 15 Loss: 0.9425
# Epoch 16 Loss: 0.9331
# Epoch 17 Loss: 0.9283
# Epoch 18 Loss: 0.9229
# Epoch 19 Loss: 0.9181
# Epoch 20 Loss: 0.9141
# Epoch 21 Loss: 0.9000
# Epoch 22 Loss: 0.8991
# Epoch 23 Loss: 0.8899
# Epoch 24 Loss: 0.8802
# Epoch 25 Loss: 0.8781
# Epoch 26 Loss: 0.8701
# Epoch 27 Loss: 0.8564
# Epoch 28 Loss: 0.8547
# Epoch 29 Loss: 0.8427
# Epoch 30 Loss: 0.8317
# Epoch 31 Loss: 0.8238
# Epoch 32 Loss: 0.8132
# Epoch 33 Loss: 0.8052
# Epoch 34 Loss: 0.7928
# Epoch 35 Loss: 0.7850
# Epoch 36 Loss: 0.7733
# ...

# %% [markdown]
# ## 2. Train the Attention IDS (Layer 2)
# Train the Intrusion Detection System using Focal Loss for class imbalance.

# %%
# !python -m training.train_ids
# Out:
# Loading dataset: nsl-kdd
# Data loaded: 8000 training samples, 2000 testing samples.
# Training Attention IDS on cuda for 30 epochs...
# Epoch 1 Loss: 0.0421 | Val Macro F1: 0.7120
# Epoch 2 Loss: 0.0340 | Val Macro F1: 0.7601
# Epoch 3 Loss: 0.0260 | Val Macro F1: 0.7906
# Epoch 4 Loss: 0.0206 | Val Macro F1: 0.8075
# Epoch 5 Loss: 0.0184 | Val Macro F1: 0.8091
# Epoch 6 Loss: 0.0176 | Val Macro F1: 0.8198
# Epoch 7 Loss: 0.0171 | Val Macro F1: 0.8304
# Epoch 8 Loss: 0.0163 | Val Macro F1: 0.8333
# Epoch 9 Loss: 0.0161 | Val Macro F1: 0.8420
# Epoch 10 Loss: 0.0154 | Val Macro F1: 0.8431
# Epoch 11 Loss: 0.0150 | Val Macro F1: 0.8490
# Epoch 12 Loss: 0.0144 | Val Macro F1: 0.8539
# Epoch 13 Loss: 0.0142 | Val Macro F1: 0.8581
# Epoch 14 Loss: 0.0132 | Val Macro F1: 0.8623
# Epoch 15 Loss: 0.0128 | Val Macro F1: 0.8690
# Epoch 16 Loss: 0.0123 | Val Macro F1: 0.8775
# Epoch 17 Loss: 0.0116 | Val Macro F1: 0.8802
# Epoch 18 Loss: 0.0111 | Val Macro F1: 0.8877
# ...

# %% [markdown]
# ## 3. Run Ablation Studies
# Evaluate clean performance vs FGSM adversarial attack vs DDPM-Purified data.

# %%
# !python -m evaluation.benchmark
# Out:
# Loading dataset: nsl-kdd
# Data loaded: 8000 training samples, 2000 testing samples.
# Running Ablation Studies over 5 seeds...
#
# --- Ablation Results ---
# clean_f1: 0.9071 ± 0.0000
# fgsm_f1: 0.7847 ± 0.0000
# purified_f1: 0.7370 ± 0.0068

# %% [markdown]
# ## 4. Test Autonomous Multi-Agent Response (Layer 3 & 4)
# Simulate processing a single incident using LangChain and RAG.

# %%
import yaml
from agents.agents import AutonomousResponseAgent

with open("configs/default.yaml", "r") as f:
    config = yaml.safe_load(f)

agent = AutonomousResponseAgent(config)
decision = agent.process_incident([0.1, -0.5, 0.9])
print("Final Autonomous Decision:", decision)
# Out:
# /content/GAICS_v2/GAICS_v2/agents/rag_pipeline.py:14: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   self.embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# ...
